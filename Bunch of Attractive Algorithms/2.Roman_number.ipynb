# %%
def greater_than_thousand(num):
    if(num>1000):
        num1=num//1000
        num=num%1000
        print(Roman_num[1000]*num1)
        less_than_thousand(num)
    else:
        less_than_thousand(num)
        
def less_than_thousand(num):
    if(num==1000):
        print(Roman_num[1000])
    elif(num>900):
        print(Roman_num[900])
        num=num%900
        less_than_hundred(num)
    else:
        #print(5)
        num1=num//500
        num=num%500
        print(Roman_num[500]*num1)
        less_than_fivehundred(num)
    

def less_than_fivehundred(num):
    if(num==400):
        print(Roman_num[400])
    elif(num>400):
        print(Roman_num[400])
        num=num%100
        less_than_hundred(num)
    else:
        #if(num>=100):
        num1=num//100
        num=num%100
        print(Roman_num[100]*num1)
        less_than_hundred(num)

def less_than_hundred(num):
    if(num==90):
        print(Roman_num[90])
    elif(num>90):
        print(Roman_num[90])
        num=num%90
        less_than_ten(num)
    else:
        #if(num>=50):
        num1=num//50
        num=num%50
        print(Roman_num[50]*num1)
        less_than_fifty(num)
            
            
def less_than_fifty(num):
    if(num==40):
        print(Roman_num[40])
    elif(num>40):
        print(Roman_num[40])
        num=num%40
        less_than_ten(num)
    else:
        #if(num>=10):
        num1=num//10
        num=num%10
        print(Roman_num[10]*num1)
        less_than_ten(num)   
        
        
def less_than_ten(num):
    if(num==9):
        print(Roman_num[9])
    elif(num>=5):
        print(Roman_num[5])
        num=num%5
        less_than_five(num)
    else:
        less_than_five(num)
            
def less_than_five(num):
    if(num==4):
        print(Roman_num[4])
    elif(num>0):
        print(Roman_num[1]*num)
        
Roman_num={1:'I',4:'IV',5:'V',9:'IX',10:'X',40:'XL',50:'L',90:'XC',100:'C',400:'CD',500:'D',900:'CM',1000:'M'}

num=int(input("Enter the number to convert it to Roman number"))

#if(num>=1000):
 #   num1=num//1000
  #  num=num%1000
   # if(num>=900):
    #    numm=num-900
    #if(num>=500):
     #   num2=num//500
      #  num=num%500
       # if(num>=100):
        #    num3=num//100
         #   num=num%100
          #  if(num>=50):
           #     num4=num//50
            #    num=num%50
    #print(Roman_num[1000]*num1+Roman_num[900]*Roman_num[500]*num2+Roman_num[100]*num3+Roman_num[50]*num4)

if(num>4000):
    print("********************Please give anumber below 4000*************************")
else:
    greater_than_thousand(num)
# Out:
# Enter the number to convert it to Roman number300
#
# CCC
